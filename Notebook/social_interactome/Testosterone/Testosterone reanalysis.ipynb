# %%
# %load_ext rmagic

# %%
# %R load("testData.RDATA"); Tassay("4-10-12 Testosterone assay melanocortin 1.txt",dil1,sampleName1)
# Out:
#       mean_OD         CV   net_OD log_concent     ng_ml sampNames seanCode
# blank 0.08980 2.99221132 -0.00140          NA        NA        NA       NA
# ta    0.29645 0.26237728  0.20525          NA        NA        NA       NA
# nsb   0.09120 0.15506728  0.00000          NA        NA        NA       NA
# bo    0.86240 3.41090470  0.77120          NA        NA        NA       NA
# std1  0.16365 0.99379505  0.07245          NA        NA        NA       NA
# std2  0.30200 1.31119138  0.21080          NA        NA        NA       NA
# std3  0.54900 0.61823544  0.45780          NA        NA        NA       NA
# std4  0.75025 2.51646132  0.65905          NA        NA        NA       NA
# std5  0.77205 1.27307613  0.68085          NA        NA        NA       NA
# 10    0.24610 3.39043479  0.15490    2.871851 22.334300        21       23
# 11    0.25035 1.66643899  0.15915    2.855761 21.522002        20       18
# ...

# %%
# %R load("testData.RDATA"); Tassay("5-3-12 melanocortin T assay.txt",dil2,sampleName2)
# Out:
#       mean_OD         CV   net_OD log_concent      ng_ml sampNames seanCode
# blank 0.09360 0.45327358 -0.00185          NA         NA        NA       NA
# ta    0.30750 0.45990685  0.21205          NA         NA        NA       NA
# nsb   0.09545 2.00019729  0.00000          NA         NA        NA       NA
# bo    0.80985 0.37544720  0.71440          NA         NA        NA       NA
# std1  0.16095 1.80126611  0.06550          NA         NA        NA       NA
# std2  0.28570 1.13849884  0.19025          NA         NA        NA       NA
# std3  0.50335 3.49795547  0.40790          NA         NA        NA       NA
# std4  0.68400 0.57891783  0.58855          NA         NA        NA       NA
# std5  0.76905 2.52850094  0.67360          NA         NA        NA       NA
# 10    0.23785 1.21889334  0.14240    2.899156 23.7835669        21       23
# 11    0.34015 0.14551661  0.24470    2.537614 10.3451075        50       49
# ...

# %%
rcode= open("testosterone reanalysis.R")
for line in rcode:
    print line
rcode.close()
# Out:
# #testosterone reanalysis with 4 parameter non-linear model for standard curves
#
# ######################################################################################
#
# load("rosetta.RDATA")
#
#
#
# txtfilename1<-"4-10-12 Testosterone assay melanocortin 1.txt"
#
# txtfilename2<-"5-3-12 melanocortin T assay.txt"
#
#
#
#
#
# save.image("testData.RDATA")
#
# sampleName1<-c(rep(NA,9),21,20,27,3,8,22,30,39,18,9,2,7,4,3,31,29,23,21,16,37,1,34,11,6,5,38,17,33,28,19,35,14,25,32,24,26,40,15,36)
#
# sampleName2<-c(rep(NA,9),21,50,43,55,52,60,49,73,75,47,59,77,48,71,56,76,44,46,74,58,68,57,64,45,72,63,61,62,51,69,70,65,42,66,67,78,54,41,79)
#
# dil1<-rep(30,48)
#
# dil1[c(20,21,23)]<-c(42,70,42)
#
# dil2<-rep(30,48)
#
# Tassay<-function(txtfilename,dil,names=rep(NA,48)){
#
#
#
# notes<-c(rep(NA,48))
#
# filename<-txtfilename
#
# master<-as.data.frame(matrix(nrow=48,ncol=5))
#
# colnames(master)<-c("mean_OD","CV","net_OD","log_concent","ng_ml")
#
# ...

# %%
# %R load("testData.RDATA"); print(intraplate); print(interplate)
# Out:
# [1] 4.444204
# [1] 1.911465
