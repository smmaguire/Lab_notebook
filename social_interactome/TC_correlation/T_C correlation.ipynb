# %%
# %load_ext rmagic

# %%
# %R load("tcCor.RDATA"); palette(c("gray50","black")); plot2py(); print("Without interaction");print(table1);print("With Interaction"); print(table2);print("T_only");print(table3); print("NT Only");print(table4)
# Out:
# [1] "Without interaction"
#              Estimate Std. Error  HPDlower  HPDupper   t value p_value
# (Intercept)  3.245614  0.3840766  2.538590 3.9918773  8.450433  0.0001
# cort        -1.011074  0.6286583 -2.517816 0.1699906 -1.608305  0.0802
# Statust      1.968388  0.3555272  1.172846 2.6570386  5.536534  0.0001
# [1] "With Interaction"
#                Estimate Std. Error  HPDlower    HPDupper     t value p_value
# (Intercept)   3.1921109  0.3809085  2.511617  3.97222556  8.38025716  0.0001
# cort          0.0360072  0.7880668 -1.825072  1.45305068  0.04569054  0.8692
# Statust       1.9528224  0.3448877  1.182644  2.61365313  5.66219761  0.0001
# cort:Statust -2.4728863  1.1937209 -4.769473 -0.04301332 -2.07157824  0.0480
# [1] "T_only"
#              Estimate Std. Error  HPDlower   HPDupper   t value p_value
# (Intercept)  5.173574  0.4850082  4.410559  5.8953560 10.666983  0.0001
# cort        -2.380333  0.9366130 -4.720047 -0.7349203 -2.541427  0.0104
# [1] "NT Only"
# ...

# %%
rcode= open("tcCor.R")
for line in rcode:
    print line
rcode.close()
# Out:
# load("alldata_updated.RDATA")
#
# hormoneData<-alldata[alldata$day==10,]
#
# library(effects); library(lme4); library(xtable)
#
# ########################## Functions ######################################
#
#
#
# get.pvalues.mcmc<-function(mcmc){
#
# hpd = lme4::HPDinterval(mcmc)
#
# mcmcfixef = t(mcmc@fixef)
#
# nr <- nrow(mcmcfixef)
#
# prop <- colSums(mcmcfixef > 0)/nr
#
# pvalues <- 2 * pmax(0.5/nr, pmin(prop, 1 - prop))
#
# modelInfo<-list(p.vals=pvalues,confint=hpd)
#
# return(modelInfo)
#
# }
#
#
#
# makeNiceTable<-function(mcmcSummary,modSummary){
#
# 	coefs<-as.data.frame(modSummary@coefs)
#
# 	coefs$p_value<-mcmcSummary$p.vals
#
# 	coefs$HPDlower<-as.data.frame(mcmcSummary$confint$fixef)$lower
#
# 	coefs$HPDupper<-as.data.frame(mcmcSummary$confint$fixef)$upper
#
# 	coefs<-coefs[,c(1,2,5,6,3,4)]
#
# 	return(coefs)
#
# }
#
# ###########################################################################
#
#
#
# names(hormoneData)[24:25]<-c("cort","test")
#
# ...

# %%
# %R library(xtable); print(xtable(table1,caption="without interaction")); print(xtable(table2,caption="with interaction")); print(xtable(table3,caption="DOM only"));print(xtable(table4,caption="SUB only"))
# Out:
# % latex table generated in R 2.15.2 by xtable 1.7-0 package
# % Thu Mar  7 13:27:45 2013
# \begin{table}[ht]
# \begin{center}
# \begin{tabular}{rrrrrrr}
#   \hline
#  & Estimate & Std. Error & HPDlower & HPDupper & t value & p\_value \\
#   \hline
# (Intercept) & 3.25 & 0.38 & 2.54 & 3.99 & 8.45 & 0.00 \\
#   cort & -1.01 & 0.63 & -2.52 & 0.17 & -1.61 & 0.08 \\
#   Statust & 1.97 & 0.36 & 1.17 & 2.66 & 5.54 & 0.00 \\
#    \hline
# \end{tabular}
# \caption{without interaction}
# \end{center}
# \end{table}
# % latex table generated in R 2.15.2 by xtable 1.7-0 package
# % Thu Mar  7 13:27:45 2013
# \begin{table}[ht]
# \begin{center}
# \begin{tabular}{rrrrrrr}
#   \hline
#  & Estimate & Std. Error & HPDlower & HPDupper & t value & p\_value \\
#   \hline
# (Intercept) & 3.19 & 0.38 & 2.51 & 3.97 & 8.38 & 0.00 \\
#   cort & 0.04 & 0.79 & -1.83 & 1.45 & 0.05 & 0.87 \\
#   Statust & 1.95 & 0.34 & 1.18 & 2.61 & 5.66 & 0.00 \\
#   cort:Statust & -2.47 & 1.19 & -4.77 & -0.04 & -2.07 & 0.05 \\
# ...

# %%
# %R library(xtable); load("hormonesxStatus.RDATA"); plot2py()
# Out:
#                Estimate Std. Error   HPDlower   HPDupper    t value p_value
# (Intercept)  0.05710384 0.08069008 -0.1043748 0.20292789  0.7076934  0.4466
# Statust     -0.11806515 0.07042638 -0.2627466 0.02353378 -1.6764335  0.1134
# % latex table generated in R 2.15.2 by xtable 1.7-0 package
# % Thu Mar  7 16:36:13 2013
# \begin{table}[ht]
# \begin{center}
# \begin{tabular}{rrrrrrr}
#   \hline
#  & Estimate & Std. Error & HPDlower & HPDupper & t value & p\_value \\
#   \hline
# (Intercept) & 0.06 & 0.08 & -0.10 & 0.20 & 0.71 & 0.45 \\
#   Statust & -0.12 & 0.07 & -0.26 & 0.02 & -1.68 & 0.11 \\
#    \hline
# \end{tabular}
# \end{center}
# \end{table}
#                Estimate Std. Error HPDlower HPDupper    t value p_value
# (Intercept)  0.05710384 0.08069008 2.369486 3.927699  0.7076934   1e-04
# Statust     -0.11806515 0.07042638 1.411476 2.866894 -1.6764335   1e-04
# % latex table generated in R 2.15.2 by xtable 1.7-0 package
# % Thu Mar  7 16:36:13 2013
# \begin{table}[ht]
# ...
